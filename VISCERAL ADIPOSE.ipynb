# %%
#loading required libraries
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# apa load the dataset tukiipea directions where to get the file itself
df = pd.read_csv( r'C:\Users\u\Downloads\visceral_fat.csv')

# %%
# apa we are just viewing the data
df.head()
# Out:
#    number  age (years)  ethnicity  diabetes mellitus  \
# 0       1           20        NaN                  0
# 1       2           28        0.0                  0
# 2       5           21        1.0                  0
# 3       9           25        0.0                  0
# 4      13           33        1.0                  0
#
#    mean diastolic bp (mmhg)  mean systolic bp (mmhg)  \
# 0                      73.5                    125.0
# 1                      75.5                    112.0
# 2                      70.5                    116.0
# 3                      92.5                    167.0
# 4                      79.0                    137.0
#
#    central armellini fat (mm) current gestational age  pregnancies (number)  \
# 0                        28.1                    12,1                   1.0
# 1                        43.1                    11,5                   1.0
# 2                        41.4                    12,6                   1.0
# ...

# %%
# we then look for basic information yenye itatusaidia in exploring this data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   number                         133 non-null    int64
#  1   age (years)                    133 non-null    int64
#  2   ethnicity                      132 non-null    float64
#  3   diabetes mellitus              133 non-null    int64
#  4   mean diastolic bp (mmhg)       133 non-null    float64
#  5   mean systolic bp (mmhg)        133 non-null    float64
#  6   central armellini fat (mm)     133 non-null    float64
#  7   current gestational age        133 non-null    object
#  8   pregnancies (number)           128 non-null    float64
#  9   first fasting glucose (mg/dl)  103 non-null    float64
#  10  bmi pregestational (kg/m)      132 non-null    float64
#  11  gestational age at birth       133 non-null    object
# ...

# %%
#we can then describe the data
df.describe()
# Out:
#            number  age (years)   ethnicity  diabetes mellitus  \
# count  133.000000   133.000000  132.000000         133.000000
# mean   161.248120    25.804511    0.439394           0.007519
# std     82.703505     6.366887    0.498204           0.086711
# min      1.000000    15.000000    0.000000           0.000000
# 25%     78.000000    21.000000    0.000000           0.000000
# 50%    187.000000    25.000000    0.000000           0.000000
# 75%    228.000000    30.000000    1.000000           0.000000
# max    287.000000    43.000000    1.000000           1.000000
#
#        mean diastolic bp (mmhg)  mean systolic bp (mmhg)  \
# count                133.000000               133.000000
# mean                  70.593985               116.578947
# std                    8.657662                13.879602
# min                   51.500000                90.000000
# 25%                   64.500000               107.000000
# 50%                   70.000000               114.000000
# ...

# %%
# next step is to duplicate the values. This will show the number of duplicate values if they are present in the data
df.duplicated().sum()
# Out:
# 0

# %%
# unique values
df['number'].unique()
df['age (years)'].unique()
df['ethnicity'].unique()
df['diabetes mellitus'].unique()
df['mean diastolic bp (mmhg)'].unique()
df['mean systolic bp (mmhg)'].unique()
df['central armellini fat (mm)'].unique()
df['current gestational age'].unique()
df['pregnancies (number)'].unique()
df['first fasting glucose (mg/dl)'].unique()
df['bmi pregestational (kg/m)'].unique()
df['gestational age at birth'].unique()
df['type of delivery'].unique()
df['child birth weight (g)'].unique()
df['gestational dm'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
#plotting the unique values



sns.countplot(df['child birth weight (g)']).unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 5
#       1 #plotting the unique values
# ----> 5 sns.countplot(df['child birth weight (g)']).unique()
#
# AttributeError: 'Axes' object has no attribute 'unique'

# %%
#finding null values

df.isnull().sum()
# Out:
# number                            0
# age (years)                       0
# ethnicity                         1
# diabetes mellitus                 0
# mean diastolic bp (mmhg)          0
# mean systolic bp (mmhg)           0
# central armellini fat (mm)        0
# current gestational age           0
# pregnancies (number)              5
# first fasting glucose (mg/dl)    30
# bmi pregestational (kg/m)         1
# gestational age at birth          0
# type of delivery                  0
# child birth weight (g)            0
# gestational dm                    0
# dtype: int64

# %%
#replacing the null values
df.replace(np.nan, '0',inplace = True )

# %%
#confirming the null values have been replaced
df.isnull().sum()
# Out:
# number                           0
# age (years)                      0
# ethnicity                        0
# diabetes mellitus                0
# mean diastolic bp (mmhg)         0
# mean systolic bp (mmhg)          0
# central armellini fat (mm)       0
# current gestational age          0
# pregnancies (number)             0
# first fasting glucose (mg/dl)    0
# bmi pregestational (kg/m)        0
# gestational age at birth         0
# type of delivery                 0
# child birth weight (g)           0
# gestational dm                   0
# dtype: int64

# %%
# here we need to know the kind of data types we are working with
df.dtypes
# Out:
# number                             int64
# age (years)                        int64
# ethnicity                         object
# diabetes mellitus                  int64
# mean diastolic bp (mmhg)         float64
# mean systolic bp (mmhg)          float64
# central armellini fat (mm)       float64
# current gestational age           object
# pregnancies (number)              object
# first fasting glucose (mg/dl)     object
# bmi pregestational (kg/m)         object
# gestational age at birth          object
# type of delivery                   int64
# child birth weight (g)             int64
# gestational dm                     int64
# dtype: object

# %%
#we now filter the data
df[df['type of delivery']==1].head()
# Out:
#     number  age (years) ethnicity  diabetes mellitus  \
# 0        1           20         0                  0
# 4       13           33       1.0                  0
# 8       20           17       1.0                  0
# 14      37           20       0.0                  0
# 19      43           18       1.0                  0
#
#     mean diastolic bp (mmhg)  mean systolic bp (mmhg)  \
# 0                       73.5                    125.0
# 4                       79.0                    137.0
# 8                       59.5                     96.5
# 14                      74.0                    129.0
# 19                      61.0                    106.5
#
#     central armellini fat (mm) current gestational age pregnancies (number)  \
# 0                         28.1                    12,1                  1.0
# 4                         67.8                    11,2                  2.0
# 8                         21.1                    13,0                  1.0
# ...

# %%
#creating a box plot
df[['type of delivery']].boxplot()
# Out:
# <Axes: >

# %%
#coorelation plot of the EDA
df.corr()
# Out:
# C:\Users\u\AppData\Local\Temp\ipykernel_6752\3961483249.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                               number  age (years)  diabetes mellitus  \
# number                      1.000000     0.045369           0.096927
# age (years)                 0.045369     1.000000           0.071294
# diabetes mellitus           0.096927     0.071294           1.000000
# mean diastolic bp (mmhg)    0.034502     0.225111          -0.005994
# mean systolic bp (mmhg)    -0.001047     0.155386           0.046713
# central armellini fat (mm)  0.211247     0.279668           0.035107
# type of delivery           -0.029876    -0.068620          -0.048992
# child birth weight (g)      0.044642     0.090276          -0.076186
# ...

# %%
#another coorelation plot using a heatmap

sns.heatmap(df.corr())
# Out:
# C:\Users\u\AppData\Local\Temp\ipykernel_6752\2325955823.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >
